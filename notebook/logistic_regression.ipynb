# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Load LR

# %%
from logistic_regression import LogisticRegression
from logistic_regression import loadDataSet

# %% [markdown]
# # Run
# 1. Please visit logistic_regression.py to see the detail

# %%
x, y = loadDataSet('logistic_regression_data.txt')
lr = LogisticRegression(x, y)
lr.stocGradAscent1()
lr.plot()
